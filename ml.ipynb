# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from os import name
from sklearn.datasets import load_diabetes

# %%
ld = load_diabetes()

# %%
ld.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
print(ld.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
print(ld.data)
# Out:
# [[ 0.03807591  0.05068012  0.06169621 ... -0.00259226  0.01990749
#   -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 ... -0.03949338 -0.06833155
#   -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 ... -0.00259226  0.00286131
#   -0.02593034]
#  ...
#  [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04688253
#    0.01549073]
#  [-0.04547248 -0.04464164  0.03906215 ...  0.02655962  0.04452873
#   -0.02593034]
#  [-0.04547248 -0.04464164 -0.0730303  ... -0.03949338 -0.00422151
#    0.00306441]]

# %%
print(ld.feature_names)
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
print(ld.target)
# Out:
# [151.  75. 141. 206. 135.  97. 138.  63. 110. 310. 101.  69. 179. 185.
#  118. 171. 166. 144.  97. 168.  68.  49.  68. 245. 184. 202. 137.  85.
#  131. 283. 129.  59. 341.  87.  65. 102. 265. 276. 252.  90. 100.  55.
#   61.  92. 259.  53. 190. 142.  75. 142. 155. 225.  59. 104. 182. 128.
#   52.  37. 170. 170.  61. 144.  52. 128.  71. 163. 150.  97. 160. 178.
#   48. 270. 202. 111.  85.  42. 170. 200. 252. 113. 143.  51.  52. 210.
#   65. 141.  55. 134.  42. 111.  98. 164.  48.  96.  90. 162. 150. 279.
#   92.  83. 128. 102. 302. 198.  95.  53. 134. 144. 232.  81. 104.  59.
#  246. 297. 258. 229. 275. 281. 179. 200. 200. 173. 180.  84. 121. 161.
#   99. 109. 115. 268. 274. 158. 107.  83. 103. 272.  85. 280. 336. 281.
#  118. 317. 235.  60. 174. 259. 178. 128.  96. 126. 288.  88. 292.  71.
#  197. 186.  25.  84.  96. 195.  53. 217. 172. 131. 214.  59.  70. 220.
#  268. 152.  47.  74. 295. 101. 151. 127. 237. 225.  81. 151. 107.  64.
# ...

# %%
dataset = pd.DataFrame(ld.data,columns=ld.feature_names)

# %%
dataset
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
dataset.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
dataset['progression']=ld.target

# %%
dataset.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  progression
# 0 -0.002592  0.019907 -0.017646        151.0
# 1 -0.039493 -0.068332 -0.092204         75.0
# 2 -0.002592  0.002861 -0.025930        141.0
# 3  0.034309  0.022688 -0.009362        206.0
# 4 -0.002592 -0.031988 -0.046641        135.0

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          442 non-null    float64
#  1   sex          442 non-null    float64
#  2   bmi          442 non-null    float64
#  3   bp           442 non-null    float64
#  4   s1           442 non-null    float64
#  5   s2           442 non-null    float64
#  6   s3           442 non-null    float64
#  7   s4           442 non-null    float64
#  8   s5           442 non-null    float64
#  9   s6           442 non-null    float64
#  10  progression  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
dataset.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.268604e-17  1.130318e-17
# ...

# %%
dataset.isnull().sum()
# Out:
# age            0
# sex            0
# bmi            0
# bp             0
# s1             0
# s2             0
# s3             0
# s4             0
# s5             0
# s6             0
# progression    0
# dtype: int64

# %%
dataset.corr()
# Out:
#                   age       sex       bmi        bp        s1        s2  \
# age          1.000000  0.173737  0.185085  0.335428  0.260061  0.219243
# sex          0.173737  1.000000  0.088161  0.241010  0.035277  0.142637
# bmi          0.185085  0.088161  1.000000  0.395411  0.249777  0.261170
# bp           0.335428  0.241010  0.395411  1.000000  0.242464  0.185548
# s1           0.260061  0.035277  0.249777  0.242464  1.000000  0.896663
# s2           0.219243  0.142637  0.261170  0.185548  0.896663  1.000000
# s3          -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455
# s4           0.203841  0.332115  0.413807  0.257650  0.542207  0.659817
# s5           0.270774  0.149916  0.446157  0.393480  0.515503  0.318357
# s6           0.301731  0.208133  0.388680  0.390430  0.325717  0.290600
# progression  0.187889  0.043062  0.586450  0.441482  0.212022  0.174054
#
#                    s3        s4        s5        s6  progression
# ...

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
import seaborn as sns
sns.regplot(x='bp',y='progression',data=dataset)
# Out:
# <Axes: xlabel='bp', ylabel='progression'>

# %%
x = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
x.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
y.head()
# Out:
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# Name: progression, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=23)

# %%
x_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 77  -0.096328 -0.044642 -0.036385 -0.074527 -0.038720 -0.027618  0.015505
# 30  -0.060003 -0.044642  0.044451 -0.019442 -0.009825 -0.007577  0.022869
# 58   0.041708 -0.044642 -0.064408  0.035644  0.012191 -0.057994  0.181179
# 29   0.067136  0.050680 -0.006206  0.063187 -0.042848 -0.095885  0.052322
# 138  0.034443  0.050680  0.111276  0.076958 -0.031840 -0.033881 -0.021311
# ..        ...       ...       ...       ...       ...       ...       ...
# 31  -0.023677 -0.044642 -0.065486 -0.081413 -0.038720 -0.053610  0.059685
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 40   0.005383  0.050680 -0.008362  0.021872  0.054845  0.073215 -0.024993
# 230 -0.038207  0.050680  0.071397 -0.057313  0.153914  0.155887  0.000779
# 83  -0.038207 -0.044642  0.009961 -0.046985 -0.059359 -0.052983 -0.010266
#
#            s4        s5        s6
# 77  -0.039493 -0.074093 -0.001078
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x_train = sc.fit_transform(x_train)

# %%
x_test = sc.transform(x_test)

# %%
import pickle
pickle.dump(sc,open('scaling.pkl','wb'))

# %%
x_train
# Out:
# array([[-1.91980497, -0.9221168 , -0.75468327, ..., -0.79954474,
#         -1.56538823,  0.04374955],
#        [-1.17342886, -0.9221168 ,  0.99604594, ..., -0.79954474,
#         -0.52865394, -0.1364986 ],
#        [ 0.91642427, -0.9221168 , -1.36160273, ..., -1.59831397,
#          0.05672262, -1.03773932],
#        ...,
#        [ 0.17004815,  1.08446131, -0.14776381, ...,  0.79799373,
#          0.34729799,  2.11660322],
#        [-0.72560319,  1.08446131,  1.57962234, ...,  1.61273835,
#          1.18018682,  1.57585878],
#        [-0.72560319, -0.9221168 ,  0.24906814, ..., -0.79954474,
#         -0.28295275, -0.85749118]])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
# Out:
# [  0.39329175 -13.09903335  25.72875231  13.11547653 -50.74698326
#   32.73585101  10.79068697  11.07427559  39.19139523   4.14394257]

# %%
print(lr.intercept_)
# Out:
# 149.2233009708738

# %%
pred = lr.predict(x_test)

# %%
pred
# Out:
# array([293.35094809, 127.10218755, 144.72503438,  30.31185458,
#        201.05274366, 199.10992282, 196.97832383, 150.78449591,
#        215.1012231 , 215.16325844, 137.19003911,  98.26671206,
#        182.34718314,  83.89644829, 105.88705115, 189.32013399,
#        233.57005261, 195.97674108, 146.34996601,  77.23562972,
#        290.00563194, 142.94830819, 158.91097584, 176.92633714,
#        120.18814384, 153.08384513, 164.69695946, 156.1600633 ,
#        296.80086743,  97.83385962, 165.17834164, 249.73455247,
#        157.06494034,  89.16929811, 182.10213794, 232.24039496,
#        136.27601684, 150.84650533, 186.24539352, 124.00900097,
#        161.07269186, 253.85031728,  62.91463742, 150.92632489,
#         75.97590842, 264.15555347, 184.16426444,  47.7015178 ,
#        187.56600186, 103.02746353, 160.80954268, 122.42283502,
#        237.87460054, 186.73784712, 230.86750678, 104.83150051,
#        269.82284758,  80.72452844, 181.71330685, 239.29571273,
# ...

# %%
plt.scatter(y_test,pred)

# %%
residuals = y_test - pred

# %%
residuals
# Out:
# 114   -35.350948
# 261   -24.102188
# 193   -28.725034
# 110    73.688145
# 357    19.947256
#          ...
# 309     2.932607
# 391    12.849671
# 179   -17.750878
# 303     6.683700
# 412    21.206275
# Name: progression, Length: 133, dtype: float64

# %%
sns.displot(residuals,kind='kde')

# %%
plt.scatter(pred,residuals)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print(mean_absolute_error(y_test,pred))
print(mean_squared_error(y_test,pred))
print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 41.24748433562721
# 2778.4694718290116
# 52.71118924696171

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,pred)
print(score)
# Out:
# 0.5098209505965337

# %% [markdown]
# prediction for new data set

# %%
ld.data[0].reshape(1,-1)
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621,  0.02187239, -0.0442235 ,
#         -0.03482076, -0.04340085, -0.00259226,  0.01990749, -0.01764613]])

# %%
sc.transform(ld.data[0].reshape(1,-1))
# Out:
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 8.41786654e-01,  1.08446131e+00,  1.36953484e+00,
#          4.74869027e-01, -9.52682499e-01, -7.70943878e-01,
#         -9.76056111e-01, -7.75504110e-04,  5.09690182e-01,
#         -3.16746740e-01]])

# %%
lr.predict(sc.transform(ld.data[0].reshape(1,-1)))
# Out:
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([208.04377384])

# %% [markdown]
# pickling the model file for deployment

# %%
import pickle

# %%
pickle.dump(lr,open('model.pkl','wb'))

# %%
pickled_model = pickle.load(open('model.pkl','rb'))

# %%
pickled_model.predict(sc.transform(ld.data[0].reshape(1,-1)))
# Out:
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([208.04377384])
